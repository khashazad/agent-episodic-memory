# %%
import chromadb
from pprint import pprint

client = chromadb.HttpClient(host='localhost', port=8000)

client.list_collections()

collection = client.get_collection("episodic_memory")

collection.count()

# pprint(collection.peek())

collection.get(include=["embeddings", "documents"],limit=10)
# Out:
# {'ids': ['v3_absolute_grape_changeling-15_10696-12887_chunk_000',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_001',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_002',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_003',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_004',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_005',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_006',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_007',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_008',
#   'v3_absolute_grape_changeling-15_10696-12887_chunk_009'],
#  'embeddings': array([[ 0.1171118 , -0.41156763,  0.47736245, ..., -0.68594986,
#          -0.8488589 , -0.4639431 ],
#         [-0.4261528 , -1.8504984 ,  0.3528831 , ..., -0.78138137,
#          -0.641079  , -0.63915014],
#         [-0.20503911, -1.7150749 ,  0.5534309 , ..., -0.71306187,
#          -0.5202373 , -0.69763577],
#         ...,
#         [-0.22645123, -1.9437909 ,  0.07876901, ..., -0.35871133,
#          -0.7075371 , -0.49832714],
#         [ 0.03077346, -2.408751  ,  0.29955012, ..., -0.3150527 ,
#          -1.0359408 , -0.64397824],
#         [ 0.07968019, -2.541804  ,  0.33458188, ..., -0.31677982,
#          -1.1156864 , -0.6379502 ]], shape=(10, 512)),
#  'metadatas': None,
#  'documents': ['forward + camera(-0.1, 0.2)\nforward + camera(-0.0, 0.2)\nforward\nforward\nforward + camera(0.4, -1.2)\nforward + camera(1.7, -1.9)\nforward + camera(1.8, -1.1)\nforward + camera(4.7, -1.2)\nforward + camera(3.6, -0.0)\nforward + camera(0.6, -0.0)\nforward\nforward\nforward\nforward\nforward\nforward',
#   'forward\nforward\nforward\nforward\nforward\nforward\nforward\nforward\nforward\nforward + jump\nforward + jump + camera(-0.3, 0.6)\nforward + jump + camera(-3.8, 3.0)\nforward + camera(-9.8, 4.9)\nforward + camera(-4.1, 0.9)\nforward + camera(-2.3, 0.2)\nforward',
#   'forward\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack + camera(-0.3, -0.0)\nattack + camera(-1.1, -0.5)\nattack + camera(-1.9, -0.5)\nattack + camera(-0.6, -0.0)\nattack\nattack + camera(-0.1, -0.0)\nattack + camera(-0.1, -0.0)\nattack + camera(-1.1, -0.0)',
#   'attack + camera(-0.8, -0.2)\nattack + camera(-0.7, -0.2)\nattack + camera(-0.1, -0.0)\nattack\nattack\nattack\nattack\nattack\nattack\nattack + camera(-2.4, -0.6)\nattack + camera(-4.7, -0.6)\nattack + camera(-6.3, -0.0)\nattack + camera(-1.0, -0.0)\nattack + camera(-0.1, -0.0)\nattack\nattack',
#   'attack\nattack\nattack\nattack + camera(0.1, -0.0)\nattack + camera(0.1, -0.0)\nattack\nattack\nattack + camera(-4.9, -0.0)\nattack + camera(-3.6, 0.5)\nattack + camera(-2.3, 0.3)\nattack + camera(-0.9, -0.0)\nattack + camera(-0.3, -0.0)\nattack + camera(-1.7, -0.0)\nattack + camera(-0.9, -0.2)\nattack + camera(-0.5, -0.2)\nattack',
#   'attack + camera(-0.0, -0.2)\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nforward + jump + attack\nforward + jump\nforward + jump\nforward + jump',
#   'forward + jump\nforward + camera(-1.7, -0.0)\nforward + camera(-5.6, -0.4)\ncamera(-4.8, -1.3)\nattack + camera(-0.6, -0.3)\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack\nattack',
#   'attack\nattack\nattack\nattack + camera(-0.2, -0.0)\nattack + camera(-0.2, -0.0)\nattack + camera(-0.2, -0.0)\nattack\nattack + camera(-0.2, -0.2)\nattack + camera(-0.2, -0.0)\nattack + camera(-3.4, -1.1)\nattack + camera(-4.5, -0.5)\nattack + camera(-5.4, -0.0)\nattack + camera(-2.0, -0.0)\nattack + camera(-0.2, -0.0)\nattack\nattack',
#   'attack\nattack\nattack\nattack + reward=4.0\nattack\nattack\nattack\nattack\nattack\nattack\nattack + camera(0.8, -0.0)\nattack + camera(5.4, -0.0)\nattack + camera(3.5, -0.0)\nattack + camera(0.6, -0.0)\nattack\nattack',
#   'attack\nattack\nattack\nattack\nattack\nattack\nattack + reward=1.0\nattack\nattack\nattack\nattack\nattack\nattack + camera(-0.2, -0.0)\nidle\nidle\nidle'],
#  'data': None,
#  'uris': None,
#  'included': ['embeddings', 'documents']}
