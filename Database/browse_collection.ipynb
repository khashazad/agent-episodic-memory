# %%
import chromadb
from pprint import pprint

client = chromadb.HttpClient(host='localhost', port=8000)

client.list_collections()

collection = client.get_collection("episodic_memory")

collection.count()

# pprint(collection.peek())

collection.get(include=["embeddings", "documents"],limit=10)
# Out:
# {'ids': ['v3_absolute_grape_changeling-15_10696-12887_window_000',
#   'v3_absolute_grape_changeling-15_10696-12887_window_001',
#   'v3_absolute_grape_changeling-15_10696-12887_window_002',
#   'v3_absolute_grape_changeling-15_10696-12887_window_003',
#   'v3_absolute_grape_changeling-15_10696-12887_window_004',
#   'v3_absolute_grape_changeling-15_10696-12887_window_005',
#   'v3_absolute_grape_changeling-15_10696-12887_window_006',
#   'v3_absolute_grape_changeling-15_10696-12887_window_007',
#   'v3_absolute_grape_changeling-15_10696-12887_window_008',
#   'v3_absolute_grape_changeling-15_10696-12887_window_009'],
#  'embeddings': array([[ 0.11711054, -0.41156787,  0.47736183, ..., -0.68595046,
#          -0.8488581 , -0.46394324],
#         [-0.04006306, -1.1401533 ,  0.2923891 , ..., -0.7243694 ,
#          -0.70545703, -0.56179667],
#         [-0.42615277, -1.8504982 ,  0.35288322, ..., -0.7813823 ,
#          -0.64107877, -0.63915014],
#         ...,
#         [-0.38015446, -2.1650805 ,  0.3399545 , ..., -0.5692942 ,
#          -0.5788908 , -0.69055414],
#         [-0.4154753 , -2.2005787 ,  0.2832265 , ..., -0.5944339 ,
#          -0.66397214, -0.6815659 ],
#         [-0.36015588, -2.198393  ,  0.26967365, ..., -0.629568  ,
#          -0.7091721 , -0.69252753]], shape=(10, 512)),
#  'metadatas': None,
#  'documents': ['"Jump to avoid falling."',
#   '"Jump to avoid falling."',
#   '"Jump to avoid falling."',
#   '"Jump to avoid falling."',
#   '"Jump to avoid falling."',
#   'Jump forward to reach the tree.',
#   'Jump forward to reach the tree.',
#   'Jump forward to reach the tree.',
#   '"Jump to avoid falling."',
#   'Jump forward to reach the tree.'],
#  'data': None,
#  'uris': None,
#  'included': ['embeddings', 'documents']}
